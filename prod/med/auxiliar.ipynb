# %% [markdown]
# Arquivo feito para testar endpoints manualmente

# %%
import pyodbc
import json
import requests
import pandas as pd

import navegadores_json

DRIVER_NAME = 'ODBC Driver 17 for SQL Server'
SERVER_NAME = '.'
DATABASE_NAME = 'ic'

CONNECTION_STRING = (
    f'DRIVER={{{DRIVER_NAME}}};'
    f'SERVER={SERVER_NAME};'
    f'DATABASE={DATABASE_NAME};'
    'Trusted_Connection=yes;'
)

conn = pyodbc.connect(CONNECTION_STRING)
cursor = conn.cursor()

# %%
sql = """
    SELECT e.Example
    FROM [Endpoints da API] as e
    where e.Id = 470
"""

cursor.execute(sql)
rows = cursor.fetchall()

print(rows)

api = rows[0][0]
# Out:
# [('https://dadosabertos.camara.leg.br/api/v2/proposicoes/276180/autores',)]

# %%
try:
    resposta = requests.get(api, params={}, timeout=240)
    
    if resposta.status_code == 200:

        print("✅ Requisição bem-sucedida (Status 200).")
        # dados_json = navegadores_json.navegador_id16(resposta.json())
        dados_json = resposta.json()
        print(dados_json)

    else:
        print(f"❌ Erro na requisição: Status Code {resposta.status_code}")
        print(f"Detalhes do erro: {resposta.text}")
        
except requests.exceptions.RequestException as e:
    print(f"❌ Ocorreu um erro ao tentar se conectar à API: {e}")
# Out:
# ✅ Requisição bem-sucedida (Status 200).
# {'dados': [{'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73764', 'nome': 'Abelardo Lupion', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 113, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73765', 'nome': 'Affonso Camargo', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 114, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73979', 'nome': 'Alceste Almeida', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 140, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73458', 'nome': 'Alex Canziani', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 115, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74675', 'nome': 'Almerinda de Carvalho', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 120, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74341', 'nome': 'Almir Sá', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 137, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74260', 'nome': 'Amauri Gasques', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 168, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74471', 'nome': 'André de Paula', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 97, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74168', 'nome': 'André Luiz', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 125, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74212', 'nome': 'Aníbal Gomes', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 22, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73928', 'nome': 'Ann Pontes', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 85, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74452', 'nome': 'Antonio Cambraia', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 25, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73817', 'nome': 'Antonio Cruz', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 78, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74194', 'nome': 'Antonio Joaquim', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 43, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74103', 'nome': 'Ariosto Holanda', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 27, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73434', 'nome': 'Arnaldo Faria de Sá', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 1, 'proponente': 1}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74291', 'nome': 'Arnon Bezerra', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 26, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74378', 'nome': 'Assis Miguel do Couto', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 107, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73889', 'nome': 'Augusto Nardes', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 145, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74349', 'nome': 'Babá', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 83, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74517', 'nome': 'Benedito de Lira', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 6, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74040', 'nome': 'Benjamin Maranhão', 'codTipo': 10000, 'tipo': 'Deputado(a)', 'ordemAssinatura': 91, 'proponente': 0}, {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74169', 'nome': 'Bernardo ...

# %%
dados_json.keys()
# Out:
# dict_keys(['dados', 'links'])

# %%
dados_json["dados"]
# Out:
# [{'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73764',
#   'nome': 'Abelardo Lupion',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 113,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73765',
#   'nome': 'Affonso Camargo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 114,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73979',
#   'nome': 'Alceste Almeida',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 140,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73458',
#   'nome': 'Alex Canziani',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 115,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74675',
#   'nome': 'Almerinda de Carvalho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 120,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74341',
#   'nome': 'Almir Sá',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 137,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74260',
#   'nome': 'Amauri Gasques',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 168,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74471',
#   'nome': 'André de Paula',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 97,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74168',
#   'nome': 'André Luiz',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 125,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74212',
#   'nome': 'Aníbal Gomes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 22,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73928',
#   'nome': 'Ann Pontes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 85,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74452',
#   'nome': 'Antonio Cambraia',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 25,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73817',
#   'nome': 'Antonio Cruz',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 78,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74194',
#   'nome': 'Antonio Joaquim',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 43,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74103',
#   'nome': 'Ariosto Holanda',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 27,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73434',
#   'nome': 'Arnaldo Faria de Sá',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 1,
#   'proponente': 1},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74291',
#   'nome': 'Arnon Bezerra',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 26,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74378',
#   'nome': 'Assis Miguel do Couto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 107,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73889',
#   'nome': 'Augusto Nardes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 145,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74349',
#   'nome': 'Babá',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 83,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74517',
#   'nome': 'Benedito de Lira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 6,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74040',
#   'nome': 'Benjamin Maranhão',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 91,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74169',
#   'nome': 'Bernardo Ariston',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 130,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74650',
#   'nome': 'Bonifácio de Andrada',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 74,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74052',
#   'nome': 'Bosco Costa',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 152,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74466',
#   'nome': 'Carlos Dunga',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 88,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74484',
#   'nome': 'Carlos Mota',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 66,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73825',
#   'nome': 'Carlos Nader',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 127,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74835',
#   'nome': 'Carlos Santana',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 121,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74148',
#   'nome': 'Carlos Willian',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 64,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74799',
#   'nome': 'Celcita Pinheiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 79,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74149',
#   'nome': 'César Medeiros',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 56,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74379',
#   'nome': 'Cezar Silvestri',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 112,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74171',
#   'nome': 'Chico Alencar',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 122,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74313',
#   'nome': 'Ciro Nogueira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 103,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74230',
#   'nome': 'Colbert Martins',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 18,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74380',
#   'nome': 'Colombo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 106,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74097',
#   'nome': 'Confúcio Moura',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 134,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74538',
#   'nome': 'Coriolano Sales',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 17,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74016',
#   'nome': 'Costa Ferreira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 46,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74187',
#   'nome': 'Darci Coelho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 173,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73924',
#   'nome': 'Davi Alcolumbre',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 13,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74468',
#   'nome': 'Domiciano Cabral',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 94,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74343',
#   'nome': 'Dr. Benedito Dias',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 11,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74150',
#   'nome': 'Dr. Francisco Gonçalves',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 51,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73920',
#   'nome': 'Dr. Rodolfo Pereira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 138,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74580',
#   'nome': 'Edmar Moreira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 49,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74061',
#   'nome': 'Edson Duarte',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 20,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74655',
#   'nome': 'Eduardo Barbosa',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 72,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74173',
#   'nome': 'Eduardo Cunha',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 119,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73945',
#   'nome': 'Eduardo Gomes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 176,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74268',
#   'nome': 'Elimar Máximo Damasceno',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 167,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73893',
#   'nome': 'Enio Bacci',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 146,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74402',
#   'nome': 'Enio Tatico',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 42,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74408',
#   'nome': 'Enivaldo Ribeiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 86,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74542',
#   'nome': 'Félix Mendonça',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 16,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74063',
#   'nome': 'Fernando de Fabinho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 19,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74658',
#   'nome': 'Fernando Diniz',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 61,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74480',
#   'nome': 'Francisco Appio',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 143,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74355',
#   'nome': 'Francisco Garcia',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 10,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73981',
#   'nome': 'Francisco Rodrigues',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 141,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74066',
#   'nome': 'Gervásio Oliveira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 12,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74778',
#   'nome': 'Gilberto Kassab',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 163,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74270',
#   'nome': 'Gilberto Nascimento',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 164,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74294',
#   'nome': 'Gonzaga Mota',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 23,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74489',
#   'nome': 'Hamilton Casara',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 136,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73582',
#   'nome': 'Helenildo Ribeiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 9,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74660',
#   'nome': 'Herculano Anghinetti',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 50,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73946',
#   'nome': 'Homero Barreto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 174,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74325',
#   'nome': 'Iberê Ferreira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 132,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74271',
#   'nome': 'Ildeu Araujo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 170,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74295',
#   'nome': 'Inácio Arruda',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 29,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74469',
#   'nome': 'Inaldo Leitão',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 95,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73461',
#   'nome': 'Iris Simões',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 109,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74153',
#   'nome': 'Ivo José',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 52,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74665',
#   'nome': 'Jaime Martins',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 70,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74847',
#   'nome': 'Jair Bolsonaro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 117,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74120',
#   'nome': 'João Magalhães',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 60,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73572',
#   'nome': 'João Magno',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 53,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74671',
#   'nome': 'José Carlos Elias',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 35,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74055',
#   'nome': 'José Carlos Machado',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 151,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74297',
#   'nome': 'José Linhares',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 21,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74584',
#   'nome': 'José Militão',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 58,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74287',
#   'nome': 'José Roberto Arruda',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 31,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74741',
#   'nome': 'José Santana de Vasconcellos',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 69,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74351',
#   'nome': 'Josué Bengtson',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 84,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74276',
#   'nome': 'Jovino Cândido',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 165,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74317',
#   'nome': 'Júlio Cesar',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 104,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73586',
#   'nome': 'Júlio Delgado',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 68,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73942',
#   'nome': 'Júnior Betão',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 5,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74493',
#   'nome': 'Jurandir Boia',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 8,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74856',
#   'nome': 'Laura Carneiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 128,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74367',
#   'nome': 'Leandro Vilela',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 39,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73473',
#   'nome': 'Leodegar Tiscoski',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 149,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74155',
#   'nome': 'Leonardo Mattos',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 71,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74156',
#   'nome': 'Leonardo Monteiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 55,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74254',
#   'nome': 'Leonardo Picciani',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 126,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73982',
#   'nome': 'Luciano Castro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 142,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74028',
#   'nome': 'Luciano Leitoa',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 44,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73483',
#   'nome': 'Luis Carlos Heinze',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 144,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74810',
#   'nome': 'Luiz Bittencourt',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 40,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74041',
#   'nome': 'Luiz Couto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 87,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74427',
#   'nome': 'Luiz Piauhylino',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 98,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74688',
#   'nome': 'Luiz Sérgio',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 123,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74163',
#   'nome': 'Manato',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 34,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74460',
#   'nome': 'Marcelo Castro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 100,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74470',
#   'nome': 'Marcondes Gadelha',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 93,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74235',
#   'nome': 'Marcus Vicente',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 33,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/64960',
#   'nome': 'Maria Helena',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 139,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74329',
#   'nome': 'Mário Assad Júnior',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 67,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74635',
#   'nome': 'Mário Negromonte',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 14,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73947',
#   'nome': 'Maurício Rabelo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 175,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74749',
#   'nome': 'Mauro Lopes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 59,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74786',
#   'nome': 'Medeiros',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 160,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73939',
#   'nome': 'Miguel de Souza',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 135,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74483',
#   'nome': 'Milton Cardias',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 147,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74787',
#   'nome': 'Milton Monti',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 159,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74238',
#   'nome': 'Moacir Micheletto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 110,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74318',
#   'nome': 'Mussa Demes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 101,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74038',
#   'nome': 'Nélio Dias',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 131,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73781',
#   'nome': 'Nelson Meurer',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 105,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74165',
#   'nome': 'Neucimar Fraga',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 36,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74790',
#   'nome': 'Neuton Lima',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 162,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74776',
#   'nome': 'Nilton Baiano',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 32,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74359',
#   'nome': 'Nilton Capixaba',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 133,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73782',
#   'nome': 'Odílio Balbinotti',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 116,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74753',
#   'nome': 'Osmânio Pereira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 75,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73463',
#   'nome': 'Osmar Serraglio',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 111,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74191',
#   'nome': 'Osvaldo Reis',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 172,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74319',
#   'nome': 'Paes Landim',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 102,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74444',
#   'nome': 'Pastor Amarildo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 171,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73485',
#   'nome': 'Paulo José Gouvêa',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 2,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74791',
#   'nome': 'Paulo Kobayashi',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 166,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74082',
#   'nome': 'Paulo Rocha',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 82,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74047',
#   'nome': 'Paulo Rubem Santiago',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 96,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74812',
#   'nome': 'Pedro Chaves',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 41,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74449',
#   'nome': 'Pedro Fernandes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 47,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74207',
#   'nome': 'Pedro Novais',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 45,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74756',
#   'nome': 'Philemon Rodrigues',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 92,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74280',
#   'nome': 'Professor Irapuan Teixeira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 169,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74590',
#   'nome': 'Rafael Guerra',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 76,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74256',
#   'nome': 'Reinaldo Betão',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 129,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74166',
#   'nome': 'Renato Casagrande',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 37,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73557',
#   'nome': 'Ricardo Izar',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 158,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74281',
#   'nome': 'Roberto Gouveia',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 155,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73420',
#   'nome': 'Roberto Jefferson',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 124,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74305',
#   'nome': 'Roberto Pessoa',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 24,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74051',
#   'nome': 'Rogério Teófilo',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 7,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74591',
#   'nome': 'Romeu Queiroz',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 57,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74592',
#   'nome': 'Ronaldo Vasconcellos',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 65,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74184',
#   'nome': 'Ronivon Santiago',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 3,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73507',
#   'nome': 'Rose de Freitas',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 38,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74482',
#   'nome': 'Rubinelli',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 154,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74762',
#   'nome': 'Saraiva Felipe',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 63,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74211',
#   'nome': 'Sebastião Madeira',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 48,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73885',
#   'nome': 'Serafim Venzon',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 150,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74641',
#   'nome': 'Severiano Alves',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 15,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74765',
#   'nome': 'Silas Brasileiro',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 62,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73424',
#   'nome': 'Simão Sessim',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 118,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74492',
#   'nome': 'Simplício Mário',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 99,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74385',
#   'nome': 'Takayama',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 108,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73564',
#   'nome': 'Vadão Gomes',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 153,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73565',
#   'nome': 'Valdemar Costa Neto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 161,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74308',
#   'nome': 'Vicente Arruda',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 28,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74283',
#   'nome': 'Vicentinho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 157,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74593',
#   'nome': 'Virgílio Guimarães',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 54,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74768',
#   'nome': 'Vittorio Medioli',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 73,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73456',
#   'nome': 'Waldemir Moka',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 77,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74481',
#   'nome': 'Wasny de Roure',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 30,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74043',
#   'nome': 'Wellington Roberto',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 89,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74044',
#   'nome': 'Wilson Santiago',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 90,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73992',
#   'nome': 'Yeda Crusius',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 148,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/74496',
#   'nome': 'Zarattini',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 156,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73932',
#   'nome': 'Zé Lima',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 80,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73933',
#   'nome': 'Zequinha Marinho',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 81,
#   'proponente': 0},
#  {'uri': 'https://dadosabertos.camara.leg.br/api/v2/deputados/73944',
#   'nome': 'Zico Bronzeado',
#   'codTipo': 10000,
#   'tipo': 'Deputado(a)',
#   'ordemAssinatura': 4,
#   'proponente': 0}]

# %%
sql = """
    SELECT r.ResponseExample
    FROM [Respostas da API] as r
    where r.Id = 424
"""

cursor.execute(sql)
rows = cursor.fetchall()


api = rows[0][0]

dados = json.loads(api)
dados
# Out:
# {'count': 100,
#  '_embedded': {'proponentes': [{'nome': 'CLAUDEMI PEREIRA DOS SANTOS',
#     'cgccpf': '***000493**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/73ca1b22c200766eda8ee3bf1a9a3b302c59c83d58575cd2d4d0a4',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=73ca1b22c200766eda8ee3bf1a9a3b302c59c83d58575cd2d4d0a4'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'CLAUDEMI PEREIRA DOS SANTOS',
#     'UF': 'CE',
#     'total_captado': 0,
#     'municipio': 'Fortaleza'},
#    {'nome': 'Djenane Vera Eduardo ',
#     'cgccpf': '***001846**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/d3d3302c6497c122948801b4dd5cf63615295c5f2614c51c69f275',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=d3d3302c6497c122948801b4dd5cf63615295c5f2614c51c69f275'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': '',
#     'UF': 'MG',
#     'total_captado': 0,
#     'municipio': 'Contagem'},
#    {'nome': 'Amellis ComÃ©rcio e RepresentaÃ§Ãµes de CDs e DVDs Soc. Empresarial LTDA',
#     'cgccpf': '00000337000107',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/ddaf191a4c782b2acefa3ff12da5061ce53d83ef4d7881974dc393173104',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=ddaf191a4c782b2acefa3ff12da5061ce53d83ef4d7881974dc393173104'},
#     'tipo_pessoa': 'juridica',
#     'responsavel': 'Marina Abramowicz',
#     'UF': 'SP',
#     'total_captado': 0,
#     'municipio': 'SÃ£o Paulo'},
#    {'nome': 'Anna Carolina GuimarÃ£es Braga Guilherme',
#     'cgccpf': '***020771**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/8cf2afca5828c55f77b8a8b0ded987402cbdacc57d0d790a237afe',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=8cf2afca5828c55f77b8a8b0ded987402cbdacc57d0d790a237afe'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Anna Carolina GuimarÃ£es Braga Guilherme',
#     'UF': 'SP',
#     'total_captado': 0,
#     'municipio': 'AraÃ§atuba'},
#    {'nome': 'EDUARDO HAZAN',
#     'cgccpf': '***022596**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/b740287e961a202f2cff0ddf6d08da6c35f23e2f78977353eabe89',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=b740287e961a202f2cff0ddf6d08da6c35f23e2f78977353eabe89'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Eduardo Hazan',
#     'UF': 'MG',
#     'total_captado': 0,
#     'municipio': 'Belo Horizonte'},
#    {'nome': 'Luciene LeÃ£o Ã\x81vila',
#     'cgccpf': '***023706**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/bda4afde0da626e69996d4a40d3d80310de93e39b9bd3bc39f0f1f',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=bda4afde0da626e69996d4a40d3d80310de93e39b9bd3bc39f0f1f'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Luciene LeÃ£o Ã\x81vila',
#     'UF': 'MG',
#     'total_captado': 0,
#     'municipio': 'Belo Horizonte'},
#    {'nome': 'PAULINO GERALDO CABRAL DE MELLO',
#     'cgccpf': '***026407**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/53e94542d5fc604b0c5f6be4c7382aff53e64513d541dabf650990',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=53e94542d5fc604b0c5f6be4c7382aff53e64513d541dabf650990'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Fernando Antonio Vecchi Alzuguir',
#     'UF': 'RJ',
#     'total_captado': 0,
#     'municipio': 'Rio de Janeiro'},
#    {'nome': 'Cristina Cordeiro de Lima Modenese',
#     'cgccpf': '***030843**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/3ca8a1f621d7e16cb4204f5ab9dbc15e7d6bf87f4f31b448415755',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=3ca8a1f621d7e16cb4204f5ab9dbc15e7d6bf87f4f31b448415755'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'CRISTINA CORDEIRO DE LIMA MODENESE',
#     'UF': 'CE',
#     'total_captado': 0,
#     'municipio': 'Fortaleza'},
#    {'nome': 'Vanderlei JosÃ© dos Santos ',
#     'cgccpf': '***031851**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/23ca704741a468f98e96f048556ef9821c39a1909a5bb8534067f4',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=23ca704741a468f98e96f048556ef9821c39a1909a5bb8534067f4'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'vanderlei josÃ© dos santos',
#     'UF': 'MT',
#     'total_captado': 0,
#     'municipio': 'JuÃ\xadna'},
#    {'nome': 'Vildson Silva de Oliveira',
#     'cgccpf': '***034371**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/0b708fce90415a5af2ad56c464b6e4528f073291b4e673c57a950d',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=0b708fce90415a5af2ad56c464b6e4528f073291b4e673c57a950d'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Vildson Silva de Oliveira',
#     'UF': 'DF',
#     'total_captado': 150000,
#     'municipio': 'BrasÃ\xadlia'},
#    {'nome': 'MOISÃ‰S TAATE ALVES SARRAF',
#     'cgccpf': '***042882**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/4f2084eb524c1ec99b30ca834300d340029724b389090092a77cf1',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=4f2084eb524c1ec99b30ca834300d340029724b389090092a77cf1'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'MOISÃ‰S TAATE ALVES SARRAF',
#     'UF': 'PA',
#     'total_captado': 0,
#     'municipio': 'Ananindeua'},
#    {'nome': 'JEAN CARLOS BITENCOURT DA SILVA',
#     'cgccpf': '***053169**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/b7c43d06ba847f230d9497ccff3903a82c3b5f47f4521e9d50f41c',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=b7c43d06ba847f230d9497ccff3903a82c3b5f47f4521e9d50f41c'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Jean Carlos Bitencourt da Silva',
#     'UF': 'SC',
#     'total_captado': 0,
#     'municipio': 'CriciÃºma'},
#    {'nome': 'ALMEIDA PRADO EVENTOS E PRODUÃ‡Ã•ES ARTÃ\x8dSTICAS LTDA. - ME ',
#     'cgccpf': '00005957000120',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/346f365071be98ed799c77655c71c3a0ed36c3fc70a76e01cac2187f69ca',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=346f365071be98ed799c77655c71c3a0ed36c3fc70a76e01cac2187f69ca'},
#     'tipo_pessoa': 'juridica',
#     'responsavel': 'ELEN CARNEIRO DE ALMEIDA PRADO',
#     'UF': 'SP',
#     'total_captado': 0,
#     'municipio': 'SÃ£o Paulo'},
#    {'nome': 'Debora Lembi Neves',
#     'cgccpf': '***066356**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/d1e0ff1a47497c37f2295f48f7de8e7c64fc59c6b73c6252c385e0',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=d1e0ff1a47497c37f2295f48f7de8e7c64fc59c6b73c6252c385e0'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': 'Debora Lembi',
#     'UF': 'RJ',
#     'total_captado': 0,
#     'municipio': 'Rio de Janeiro'},
#    {'nome': 'NatÃ¡ssia Duarte Garcia Leite de Oliveira',
#     'cgccpf': '***067841**',
#     '_links': {'self': 'http://api.salic.cultura.gov.br/v1/proponentes/581526898dc6ae880cc02a5f9f669d49da07b3da10ac7910a5d0f3',
#      'projetos': 'http://api.salic.cultura.gov.br/v1/projetos/?proponente_id=581526898dc6ae880cc02a5f9f669d49da07b3da10ac7910a5d0f3'},
#     'tipo_pessoa': 'fisica',
#     'responsavel': '',
#     'UF': 'GO',
#     'total_captado': 0,
#     'municipio': 'GoiÃ¢nia'}]}}

# %%
dados["_embedded"]["proponentes"][0].keys()
# Out:
# dict_keys(['nome', 'cgccpf', '_links', 'tipo_pessoa', 'responsavel', 'UF', 'total_captado', 'municipio'])
